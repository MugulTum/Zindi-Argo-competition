# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold
from sklearn.impute import SimpleImputer
from scipy.stats import mstats


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load files
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')
sample_submission = pd.read_csv('SampleSubmission.csv')

# %%
# Preview the first five rows of the train set
train.head()
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_vjcx08sz91  6531a46a89b3300013914a36        6.53257         3.39936
# 1  id_bkg215syli  6531a46a89b3300013914a36        6.53257         3.39936
# 2  id_oui2pot3qd  6531a46a89b3300013914a36        6.53257         3.39936
# 3  id_9aandqzy4n  6531a46a89b3300013914a36        6.53257         3.39936
# 4  id_ali5x2m4iw  6531a46a89b3300013914a36        6.53257         3.39936
#
#     city  country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Lagos  Nigeria  2023-10-25    13                                       NaN
# 1  Lagos  Nigeria  2023-11-02    12                                       NaN
# 2  Lagos  Nigeria  2023-11-03    13                                       NaN
# 3  Lagos  Nigeria  2023-11-08    14                                       NaN
# 4  Lagos  Nigeria  2023-11-09    13                                  0.000267
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                      0.774656
#
#    sulphurdioxide_so2_slant_column_number_density  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        0.000207
#
#    sulphurdioxide_cloud_fraction  sulphurdioxide_sensor_azimuth_angle  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                       0.223403                           -97.811241
#
#    sulphurdioxide_sensor_zenith_angle  sulphurdioxide_solar_azimuth_angle  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                           49.513344                         -126.064468
#
#    sulphurdioxide_solar_zenith_angle  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                          40.167336
#
#    sulphurdioxide_so2_column_number_density_15km  month  \
# 0                                            NaN   10.0
# 1                                            NaN   11.0
# 2                                            NaN   11.0
# 3                                            NaN   11.0
# 4                                       0.000083   11.0
#
#    carbonmonoxide_co_column_number_density  \
# 0                                      NaN
# 1                                 0.045475
# 2                                      NaN
# 3                                      NaN
# 4                                 0.049045
#
#    carbonmonoxide_h2o_column_number_density  carbonmonoxide_cloud_height  \
# 0                                       NaN                          NaN
# 1                               3771.027210                  3399.756845
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                               3514.042054                  1678.370478
#
#    carbonmonoxide_sensor_altitude  carbonmonoxide_sensor_azimuth_angle  \
# 0                             NaN                                  NaN
# 1                   828569.623806                            69.245351
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                   828902.790450                           -96.099639
#
#    carbonmonoxide_sensor_zenith_angle  carbonmonoxide_solar_azimuth_angle  \
# 0                                 NaN                                 NaN
# 1                           59.159695                         -143.370575
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                           49.432796                         -126.070747
#
#    carbonmonoxide_solar_zenith_angle  \
# 0                                NaN
# 1                          26.566997
# 2                                NaN
# 3                                NaN
# 4                          40.144183
#
#    nitrogendioxide_no2_column_number_density  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                   0.000097
#
#    nitrogendioxide_tropospheric_no2_column_number_density  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000063
#
#    nitrogendioxide_stratospheric_no2_column_number_density  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000035
#
#    nitrogendioxide_no2_slant_column_number_density  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                         0.000175
#
#    nitrogendioxide_tropopause_pressure  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                          9582.712645
#
#    nitrogendioxide_absorbing_aerosol_index  nitrogendioxide_cloud_fraction  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                 0.069667                        0.142913
#
#    nitrogendioxide_sensor_altitude  nitrogendioxide_sensor_azimuth_angle  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                         828919.0                            -97.811241
#
#    nitrogendioxide_sensor_zenith_angle  nitrogendioxide_solar_azimuth_angle  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                            49.513344                          -126.064468
#
#    nitrogendioxide_solar_zenith_angle  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           40.167336
#
#    formaldehyde_tropospheric_hcho_column_number_density  \
# 0                                                NaN
# 1                                           0.000214
# 2                                                NaN
# 3                                                NaN
# 4                                           0.000100
#
#    formaldehyde_tropospheric_hcho_column_number_density_amf  \
# 0                                                NaN
# 1                                           1.462390
# 2                                                NaN
# 3                                                NaN
# 4                                           1.298433
#
#    formaldehyde_hcho_slant_column_number_density  formaldehyde_cloud_fraction  \
# 0                                            NaN                          NaN
# 1                                       0.000240                     0.359150
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                       0.000068                     0.223403
#
#    formaldehyde_solar_zenith_angle  formaldehyde_solar_azimuth_angle  \
# 0                              NaN                               NaN
# 1                        26.525513                       -143.480164
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                        40.167336                       -126.064468
#
#    formaldehyde_sensor_zenith_angle  formaldehyde_sensor_azimuth_angle  \
# 0                               NaN                                NaN
# 1                         59.220097                          70.875954
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                         49.513344                         -97.811241
#
#    uvaerosolindex_absorbing_aerosol_index  uvaerosolindex_sensor_altitude  \
# 0                                0.052301                     828817.9375
# 1                               -0.315206                     828578.6250
# 2                                1.097816                     828878.6875
# 3                                0.591543                     828920.6875
# 4                                0.069669                     828919.0000
#
#    uvaerosolindex_sensor_azimuth_angle  uvaerosolindex_sensor_zenith_angle  \
# 0                          -100.805145                           21.720518
# 1                            70.875954                           59.220097
# 2                           -96.411942                           61.045010
# 3                           -95.863083                           65.508858
# 4                           -97.811241                           49.513344
#
#    uvaerosolindex_solar_azimuth_angle  uvaerosolindex_solar_zenith_angle  \
# 0                         -123.523796                          33.745914
# 1                         -143.480164                          26.525513
# 2                         -121.307121                          41.898113
# 3                         -122.218231                          43.923038
# 4                         -126.064468                          40.167336
#
#    ozone_o3_column_number_density  ozone_o3_column_number_density_amf  \
# 0                        0.122055                            2.301404
# 1                        0.116975                            3.049902
# 2                        0.117559                            3.248703
# 3                        0.118412                            3.505708
# 4                        0.117899                            2.796072
#
#    ozone_o3_slant_column_number_density  ozone_o3_effective_temperature  \
# 0                              0.285803                      230.693756
# 1                              0.362203                      228.260193
# 2                              0.384168                      224.102463
# 3                              0.416643                      226.529633
# 4                              0.334256                      226.368851
#
#    ozone_cloud_fraction  ozone_sensor_azimuth_angle  \
# 0              0.906039                 -100.805145
# 1              0.364713                   70.875954
# 2              0.754163                  -96.411942
# 3              1.000000                  -95.863083
# 4              0.226150                  -97.811241
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  21.720518                -123.523796
# 1                  59.220097                -143.480164
# 2                  61.045010                -121.307121
# 3                  65.508858                -122.218231
# 4                  49.513344                -126.064468
#
#    ozone_solar_zenith_angle  uvaerosollayerheight_aerosol_height  \
# 0                 33.745914                                  NaN
# 1                 26.525513                                  NaN
# 2                 41.898113                                  NaN
# 3                 43.923038                                  NaN
# 4                 40.167336                                  NaN
#
#    uvaerosollayerheight_aerosol_pressure  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    uvaerosollayerheight_aerosol_optical_depth  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    uvaerosollayerheight_sensor_zenith_angle  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    uvaerosollayerheight_sensor_azimuth_angle  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    uvaerosollayerheight_solar_azimuth_angle  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    uvaerosollayerheight_solar_zenith_angle  cloud_cloud_fraction  \
# 0                                      NaN                   NaN
# 1                                      NaN                   NaN
# 2                                      NaN              0.756392
# 3                                      NaN                   NaN
# 4                                      NaN              0.226141
#
#    cloud_cloud_top_pressure  cloud_cloud_top_height  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2               45185.49959             6791.682888
# 3                       NaN                     NaN
# 4               86197.53125             1451.050659
#
#    cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2               51171.802486              5791.682829
# 3                        NaN                      NaN
# 4               96215.906250               451.050598
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                  11.816715              0.192757
# 3                        NaN                   NaN
# 4                  10.521009              0.153114
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                  -96.411890                  61.045123
# 3                         NaN                        NaN
# 4                  -97.811241                  49.513439
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle      pm2_5
# 0                        NaN                       NaN  12.015000
# 1                        NaN                       NaN  42.267200
# 2                -121.307414                 41.898269  39.450741
# 3                        NaN                       NaN  10.537600
# 4                -126.064453                 40.167355  19.431731

# %%
# Preview the first five rows of the test set
test.head()
# Out:
#               id                   site_id  site_latitude  site_longitude  \
# 0  id_ihxgrbq8bw  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 1  id_dg6s4fhiwe  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 2  id_f7hwwtmuzp  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 3  id_ioese5awdg  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
# 4  id_hdw320zpls  64f9d17ab9e98d001ac9e882        5.61252        -0.22955
#
#     city country        date  hour  sulphurdioxide_so2_column_number_density  \
# 0  Accra   Ghana  2023-09-06    13                                 -0.000072
# 1  Accra   Ghana  2023-09-07    13                                       NaN
# 2  Accra   Ghana  2023-09-08    13                                 -0.000051
# 3  Accra   Ghana  2023-09-09    12                                       NaN
# 4  Accra   Ghana  2023-09-20    12                                 -0.000634
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                                      0.762543
# 1                                           NaN
# 2                                      1.004265
# 3                                           NaN
# 4                                      0.632173
#
#    sulphurdioxide_so2_slant_column_number_density  \
# 0                                       -0.000055
# 1                                             NaN
# 2                                       -0.000051
# 3                                             NaN
# 4                                       -0.000401
#
#    sulphurdioxide_cloud_fraction  sulphurdioxide_sensor_azimuth_angle  \
# 0                       0.079645                          -100.330299
# 1                            NaN                                  NaN
# 2                       0.163160                            73.117264
# 3                            NaN                                  NaN
# 4                       0.000000                            70.066956
#
#    sulphurdioxide_sensor_zenith_angle  sulphurdioxide_solar_azimuth_angle  \
# 0                           26.926420                          -86.879776
# 1                                 NaN                                 NaN
# 2                           43.112466                          -89.089083
# 3                                 NaN                                 NaN
# 4                           66.014107                         -111.396515
#
#    sulphurdioxide_solar_zenith_angle  \
# 0                          25.512329
# 1                                NaN
# 2                          16.417355
# 3                                NaN
# 4                          12.226210
#
#    sulphurdioxide_so2_column_number_density_15km  month  \
# 0                                      -0.000028    9.0
# 1                                            NaN    9.0
# 2                                      -0.000023    9.0
# 3                                            NaN    9.0
# 4                                      -0.000147    9.0
#
#    carbonmonoxide_co_column_number_density  \
# 0                                 0.043537
# 1                                 0.036341
# 2                                 0.037453
# 3                                      NaN
# 4                                      NaN
#
#    carbonmonoxide_h2o_column_number_density  carbonmonoxide_cloud_height  \
# 0
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  26.926420                 -86.879776
# 1                  11.171532                 -87.726566
# 2                  43.112466                 -89.089083
# 3                  61.874397                 -90.875526
# 4                  66.014107                -111.396515
#
#    ozone_solar_zenith_angle  uvaerosollayerheight_aerosol_height  \
# 0                 25.512329                                  NaN
# 1                 20.951560                                  NaN
# 2                 16.417355                                  NaN
# 3                 11.865146                                  NaN
# 4                 12.226210                                  NaN
#
#    uvaerosollayerheight_aerosol_pressure  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    uvaerosollayerheight_aerosol_optical_depth  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    uvaerosollayerheight_sensor_zenith_angle  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    uvaerosollayerheight_sensor_azimuth_angle  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    uvaerosollayerheight_solar_azimuth_angle  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    uvaerosollayerheight_solar_zenith_angle  cloud_cloud_fraction  \
# 0                                      NaN              0.043065
# 1                                      NaN                   NaN
# 2                                      NaN                   NaN
# 3                                      NaN              0.845911
# 4                                      NaN                   NaN
#
#    cloud_cloud_top_pressure  cloud_cloud_top_height  \
# 0              74217.403083             2710.544562
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3              46052.449219             6585.034668
# 4                       NaN                     NaN
#
#    cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0               83569.504246              1710.544483
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3               52160.980469              5585.034668
# 4                        NaN                      NaN
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                   3.063105              0.263193
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                  29.145922              0.314945
# 4                        NaN                   NaN
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                 -100.317077                  27.059646
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                   70.680077                  61.874222
# 4                         NaN                        NaN
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle
# 0                 -86.885670                 25.530511
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                 -90.875603                 11.865201
# 4                        NaN                       NaN

# %%
# Preview the first five rows of the sample submission file
sample_submission.head()
# Out:
#               id  pm2_5
# 0  id_ihxgrbq8bw      0
# 1  id_dg6s4fhiwe      0
# 2  id_f7hwwtmuzp      0
# 3  id_ioese5awdg      0
# 4  id_hdw320zpls      0

# %%
# target distribution
plt.figure(figsize = (11, 5))
sns.histplot(train.pm2_5)
plt.title('Target Distribution')
plt.show()

# %% [markdown]
# - From the target distribution histogram we can see that the distribution is skewed to the right.
# - Some processing of the target is recommended

# %%
# Check for outliers in the target variable
plt.figure(figsize = (11, 5))
sns.boxplot(train.pm2_5)
plt.title('Boxplot showing outliers - target variable')
plt.show()

# %% [markdown]
# - The target variable has some outliers that are beyond the 180 mark.
# - Outliers can be handled via
#   - Dropping them
#   - Cap outliers - set a maximum
#   - Assign a new value to the outliers
#   - Transform the target variable

# %% [markdown]
# ## Handling Missing Values

# %%
missing_values = ((train.isna().sum())/(len(train))) * 100
missing_values_sorted = missing_values.sort_values(ascending = False)
missing_values_sorted
# Out:
# uvaerosollayerheight_aerosol_height                         94.709454
# uvaerosollayerheight_solar_zenith_angle                     94.709454
# uvaerosollayerheight_solar_azimuth_angle                    94.709454
# uvaerosollayerheight_sensor_azimuth_angle                   94.709454
# uvaerosollayerheight_sensor_zenith_angle                    94.709454
# uvaerosollayerheight_aerosol_optical_depth                  94.709454
# uvaerosollayerheight_aerosol_pressure                       94.709454
# nitrogendioxide_no2_slant_column_number_density             61.541321
# nitrogendioxide_no2_column_number_density                   61.541321
# nitrogendioxide_tropospheric_no2_column_number_density      61.541321
# nitrogendioxide_stratospheric_no2_column_number_density     61.541321
# nitrogendioxide_sensor_altitude                             61.541321
# nitrogendioxide_tropopause_pressure                         61.541321
# nitrogendioxide_absorbing_aerosol_index                     61.541321
# nitrogendioxide_cloud_fraction                              61.541321
# nitrogendioxide_solar_azimuth_angle                         61.541321
# nitrogendioxide_solar_zenith_angle                          61.541321
# nitrogendioxide_sensor_zenith_angle                         61.541321
# nitrogendioxide_sensor_azimuth_angle                        61.541321
# sulphurdioxide_solar_azimuth_angle                          60.859869
# sulphurdioxide_so2_column_number_density                    60.859869
# sulphurdioxide_so2_column_number_density_amf                60.859869
# sulphurdioxide_so2_slant_column_number_density              60.859869
# sulphurdioxide_cloud_fraction                               60.859869
# sulphurdioxide_sensor_azimuth_angle                         60.859869
# sulphurdioxide_sensor_zenith_angle                          60.859869
# sulphurdioxide_solar_zenith_angle                           60.859869
# sulphurdioxide_so2_column_number_density_15km               60.859869
# formaldehyde_sensor_zenith_angle                            48.507000
# formaldehyde_tropospheric_hcho_column_number_density        48.507000
# formaldehyde_tropospheric_hcho_column_number_density_amf    48.507000
# formaldehyde_cloud_fraction                                 48.507000
# formaldehyde_solar_zenith_angle                             48.507000
# formaldehyde_solar_azimuth_angle                            48.507000
# formaldehyde_sensor_azimuth_angle                           48.507000
# formaldehyde_hcho_slant_column_number_density               48.507000
# carbonmonoxide_h2o_column_number_density                    44.975839
# carbonmonoxide_solar_azimuth_angle                          44.975839
# carbonmonoxide_sensor_zenith_angle                          44.975839
# carbonmonoxide_sensor_azimuth_angle                         44.975839
# carbonmonoxide_sensor_altitude                              44.975839
# carbonmonoxide_cloud_height                                 44.975839
# carbonmonoxide_solar_zenith_angle                           44.975839
# carbonmonoxide_co_column_number_density                     44.975839
# cloud_sensor_zenith_angle                                   38.124148
# cloud_cloud_optical_depth                                   38.124148
# cloud_surface_albedo                                        38.124148
# cloud_sensor_azimuth_angle                                  38.124148
# cloud_cloud_top_height                                      38.124148
# cloud_solar_azimuth_angle                                   38.124148
# cloud_solar_zenith_angle                                    38.124148
# cloud_cloud_fraction                                        38.124148
# cloud_cloud_base_height                                     38.124148
# cloud_cloud_top_pressure                                    38.124148
# cloud_cloud_base_pressure                                   38.124148
# ozone_o3_slant_column_number_density                         1.387684
# ozone_o3_effective_temperature                               1.387684
# ozone_cloud_fraction                                         1.387684
# ozone_sensor_azimuth_angle                                   1.387684
# ozone_sensor_zenith_angle                                    1.387684
# ozone_solar_azimuth_angle                                    1.387684
# ozone_solar_zenith_angle                                     1.387684
# ozone_o3_column_number_density                               1.387684
# ozone_o3_column_number_density_amf                           1.387684
# uvaerosolindex_solar_zenith_angle                            0.061950
# uvaerosolindex_solar_azimuth_angle                           0.061950
# uvaerosolindex_sensor_zenith_angle                           0.061950
# uvaerosolindex_sensor_azimuth_angle                          0.061950
# uvaerosolindex_sensor_altitude                               0.061950
# uvaerosolindex_absorbing_aerosol_index                       0.061950
# id                                                           0.000000
# site_id                                                      0.000000
# month                                                        0.000000
# hour                                                         0.000000
# date                                                         0.000000
# country                                                      0.000000
# city                                                         0.000000
# site_longitude                                               0.000000
# site_latitude                                                0.000000
# pm2_5                                                        0.000000
# dtype: float64

# %%
missing_values = ((test.isna().sum())/(len(test))) * 100
missing_values_sorted = missing_values.sort_values(ascending = False)
missing_values_sorted
# Out:
# uvaerosollayerheight_aerosol_pressure                       97.700323
# uvaerosollayerheight_aerosol_optical_depth                  97.700323
# uvaerosollayerheight_sensor_zenith_angle                    97.700323
# uvaerosollayerheight_sensor_azimuth_angle                   97.700323
# uvaerosollayerheight_solar_azimuth_angle                    97.700323
# uvaerosollayerheight_solar_zenith_angle                     97.700323
# uvaerosollayerheight_aerosol_height                         97.700323
# cloud_cloud_base_pressure                                   45.957600
# cloud_cloud_fraction                                        45.957600
# cloud_cloud_top_pressure                                    45.957600
# cloud_cloud_top_height                                      45.957600
# cloud_solar_zenith_angle                                    45.957600
# cloud_solar_azimuth_angle                                   45.957600
# cloud_sensor_zenith_angle                                   45.957600
# cloud_sensor_azimuth_angle                                  45.957600
# cloud_surface_albedo                                        45.957600
# cloud_cloud_optical_depth                                   45.957600
# cloud_cloud_base_height                                     45.957600
# nitrogendioxide_no2_slant_column_number_density             39.310097
# nitrogendioxide_sensor_azimuth_angle                        39.310097
# nitrogendioxide_tropopause_pressure                         39.310097
# nitrogendioxide_sensor_altitude                             39.310097
# nitrogendioxide_stratospheric_no2_column_number_density     39.310097
# nitrogendioxide_tropospheric_no2_column_number_density      39.310097
# nitrogendioxide_no2_column_number_density                   39.310097
# nitrogendioxide_solar_zenith_angle                          39.310097
# nitrogendioxide_sensor_zenith_angle                         39.310097
# nitrogendioxide_solar_azimuth_angle                         39.310097
# nitrogendioxide_cloud_fraction                              39.310097
# nitrogendioxide_absorbing_aerosol_index                     39.310097
# sulphurdioxide_so2_column_number_density_amf                38.591448
# sulphurdioxide_so2_column_number_density                    38.591448
# sulphurdioxide_sensor_azimuth_angle                         38.591448
# sulphurdioxide_sensor_zenith_angle                          38.591448
# sulphurdioxide_so2_slant_column_number_density              38.591448
# sulphurdioxide_cloud_fraction                               38.591448
# sulphurdioxide_so2_column_number_density_15km               38.591448
# sulphurdioxide_solar_zenith_angle                           38.591448
# sulphurdioxide_solar_azimuth_angle                          38.591448
# carbonmonoxide_solar_zenith_angle                           37.046353
# carbonmonoxide_solar_azimuth_angle                          37.046353
# carbonmonoxide_sensor_azimuth_angle                         37.046353
# carbonmonoxide_sensor_altitude                              37.046353
# carbonmonoxide_cloud_height                                 37.046353
# carbonmonoxide_h2o_column_number_density                    37.046353
# carbonmonoxide_co_column_number_density                     37.046353
# carbonmonoxide_sensor_zenith_angle                          37.046353
# formaldehyde_tropospheric_hcho_column_number_density_amf    27.308660
# formaldehyde_sensor_azimuth_angle                           27.308660
# formaldehyde_sensor_zenith_angle                            27.308660
# formaldehyde_tropospheric_hcho_column_number_density        27.308660
# formaldehyde_hcho_slant_column_number_density               27.308660
# formaldehyde_cloud_fraction                                 27.308660
# formaldehyde_solar_zenith_angle                             27.308660
# formaldehyde_solar_azimuth_angle                            27.308660
# ozone_o3_column_number_density                               0.503054
# ozone_o3_column_number_density_amf                           0.503054
# ozone_o3_slant_column_number_density                         0.503054
# ozone_o3_effective_temperature                               0.503054
# ozone_cloud_fraction                                         0.503054
# ozone_sensor_azimuth_angle                                   0.503054
# ozone_sensor_zenith_angle                                    0.503054
# ozone_solar_azimuth_angle                                    0.503054
# ozone_solar_zenith_angle                                     0.503054
# uvaerosolindex_sensor_azimuth_angle                          0.035932
# uvaerosolindex_sensor_zenith_angle                           0.035932
# uvaerosolindex_absorbing_aerosol_index                       0.035932
# uvaerosolindex_sensor_altitude                               0.035932
# uvaerosolindex_solar_zenith_angle                            0.035932
# uvaerosolindex_solar_azimuth_angle                           0.035932
# site_id                                                      0.000000
# month                                                        0.000000
# hour                                                         0.000000
# date                                                         0.000000
# country                                                      0.000000
# city                                                         0.000000
# site_longitude                                               0.000000
# site_latitude                                                0.000000
# id                                                           0.000000
# dtype: float64

# %%
# Drop columns with more than 50% missing values
threshold = 0.8
train_df = train.loc[:, train.isnull().mean() < threshold]
test_df = test.loc[:, test.isnull().mean() < threshold]

# %%
# Identify the group column
group_col = 'site_id'

# Separate numerical and categorical columns
numerical_cols = train_df.select_dtypes(include=[np.number]).columns.difference(['pm2_5'])
categorical_cols = train_df.select_dtypes(exclude=[np.number]).columns

# Impute numerical columns
for column in numerical_cols:
    if column != group_col:
        print(f"Imputing numerical column: {column}")
        mean_impute = train_df.groupby(group_col)[column].transform('median')
        train_df[column] = train_df[column].fillna(mean_impute)
        train_df[column] = train_df[column].fillna(train_df[column].mean())

        mean_impute_test = test_df.groupby(group_col)[column].transform('median')
        test_df[column] = test_df[column].fillna(mean_impute_test)
        test_df[column] = test_df[column].fillna(test_df[column].mean())

# Impute categorical columns
for column in categorical_cols:
    if column != group_col:
        print(f"Imputing categorical column: {column}")
        mode_impute = train_df.groupby(group_col)[column].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
        train_df[column] = train_df[column].fillna(train_df[group_col].map(mode_impute))
        train_df[column] = train_df[column].fillna(train_df[column].mode().iloc[0] if not train_df[column].mode().empty else 'missing')

        mode_impute_test = test_df.groupby(group_col)[column].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
        test_df[column] = test_df[column].fillna(test_df[group_col].map(mode_impute_test))
        test_df[column] = test_df[column].fillna(test_df[column].mode().iloc[0] if not test_df[column].mode().empty else 'missing')
# Out:
# Imputing numerical column: carbonmonoxide_cloud_height
# Imputing numerical column: carbonmonoxide_co_column_number_density
# Imputing numerical column: carbonmonoxide_h2o_column_number_density
# Imputing numerical column: carbonmonoxide_sensor_altitude
# Imputing numerical column: carbonmonoxide_sensor_azimuth_angle
# Imputing numerical column: carbonmonoxide_sensor_zenith_angle
# Imputing numerical column: carbonmonoxide_solar_azimuth_angle
# Imputing numerical column: carbonmonoxide_solar_zenith_angle
# Imputing numerical column: cloud_cloud_base_height
# Imputing numerical column: cloud_cloud_base_pressure
# Imputing numerical column: cloud_cloud_fraction
# Imputing numerical column: cloud_cloud_optical_depth
# Imputing numerical column: cloud_cloud_top_height
# Imputing numerical column: cloud_cloud_top_pressure
# Imputing numerical column: cloud_sensor_azimuth_angle
# Imputing numerical column: cloud_sensor_zenith_angle
# Imputing numerical column: cloud_solar_azimuth_angle
# Imputing numerical column: cloud_solar_zenith_angle
# Imputing numerical column: cloud_surface_albedo
# Imputing numerical column: formaldehyde_cloud_fraction
# Imputing numerical column: formaldehyde_hcho_slant_column_number_density
# Imputing numerical column: formaldehyde_sensor_azimuth_angle
# Imputing numerical column: formaldehyde_sensor_zenith_angle
# Imputing numerical column: formaldehyde_solar_azimuth_angle
# Imputing numerical column: formaldehyde_solar_zenith_angle
# Imputing numerical column: formaldehyde_tropospheric_hcho_column_number_density
# Imputing numerical column: formaldehyde_tropospheric_hcho_column_number_density_amf
# Imputing numerical column: hour
# Imputing numerical column: month
# Imputing numerical column: nitrogendioxide_absorbing_aerosol_index
# Imputing numerical column: nitrogendioxide_cloud_fraction
# Imputing numerical column: nitrogendioxide_no2_column_number_density
# Imputing numerical column: nitrogendioxide_no2_slant_column_number_density
# Imputing numerical column: nitrogendioxide_sensor_altitude
# Imputing numerical column: nitrogendioxide_sensor_azimuth_angle
# Imputing numerical column: nitrogendioxide_sensor_zenith_angle
# Imputing numerical column: nitrogendioxide_solar_azimuth_angle
# Imputing numerical column: nitrogendioxide_solar_zenith_angle
# Imputing numerical column: nitrogendioxide_stratospheric_no2_column_number_density
# Imputing numerical column: nitrogendioxide_tropopause_pressure
# Imputing numerical column: nitrogendioxide_tropospheric_no2_column_number_density
# Imputing numerical column: ozone_cloud_fraction
# Imputing numerical column: ozone_o3_column_number_density
# Imputing numerical column: ozone_o3_column_number_density_amf
# Imputing numerical column: ozone_o3_effective_temperature
# Imputing numerical column: ozone_o3_slant_column_number_density
# Imputing numerical column: ozone_sensor_azimuth_angle
# Imputing numerical column: ozone_sensor_zenith_angle
# Imputing numerical column: ozone_solar_azimuth_angle
# Imputing numerical column: ozone_solar_zenith_angle
# Imputing numerical column: site_latitude
# Imputing numerical column: site_longitude
# Imputing numerical column: sulphurdioxide_cloud_fraction
# Imputing numerical column: sulphurdioxide_sensor_azimuth_angle
# Imputing numerical column: sulphurdioxide_sensor_zenith_angle
# Imputing numerical column: sulphurdioxide_so2_column_number_density
# Imputing numerical column: sulphurdioxide_so2_column_number_density_15km
# Imputing numerical column: sulphurdioxide_so2_column_number_density_amf
# Imputing numerical column: sulphurdioxide_so2_slant_column_number_density
# Imputing numerical column: sulphurdioxide_solar_azimuth_angle
# Imputing numerical column: sulphurdioxide_solar_zenith_angle
# Imputing numerical column: uvaerosolindex_absorbing_aerosol_index
# Imputing numerical column: uvaerosolindex_sensor_altitude
# Imputing numerical column: uvaerosolindex_sensor_azimuth_angle
# Imputing numerical column: uvaerosolindex_sensor_zenith_angle
# Imputing numerical column: uvaerosolindex_solar_azimuth_angle
# Imputing numerical column: uvaerosolindex_solar_zenith_angle
# Imputing categorical column: id
# Imputing categorical column: city
# Imputing categorical column: country
# Imputing categorical column: date

# %%
# Ensure no missing values remain
assert train_df.isnull().sum().sum() == 0, "There are still missing values in the training set."
assert test_df.isnull().sum().sum() == 0, "There are still missing values in the testing set."

print("Imputation complete and verified!")
# Out:
# Imputation complete and verified!

# %% [markdown]
# ### Using interquartile range to check for outliers

# %%
# Calculating the IQR for numerical columns
for column in numerical_cols:
    if column != 'pm2_5':  # Exclude 'pm2_5' column
        Q1 = train_df[column].quantile(0.25)
        Q3 = train_df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = ((train_df[column] < lower_bound) | (train_df[column] > upper_bound)).sum()
        print(f"Outliers in {column}: {outliers}")
# Out:
# Outliers in carbonmonoxide_cloud_height: 1065
# Outliers in carbonmonoxide_co_column_number_density: 862
# Outliers in carbonmonoxide_h2o_column_number_density: 812
# Outliers in carbonmonoxide_sensor_altitude: 1062
# Outliers in carbonmonoxide_sensor_azimuth_angle: 0
# Outliers in carbonmonoxide_sensor_zenith_angle: 1299
# Outliers in carbonmonoxide_solar_azimuth_angle: 0
# Outliers in carbonmonoxide_solar_zenith_angle: 1225
# Outliers in cloud_cloud_base_height: 387
# Outliers in cloud_cloud_base_pressure: 51
# Outliers in cloud_cloud_fraction: 0
# Outliers in cloud_cloud_optical_depth: 1025
# Outliers in cloud_cloud_top_height: 387
# Outliers in cloud_cloud_top_pressure: 57
# Outliers in cloud_sensor_azimuth_angle: 0
# Outliers in cloud_sensor_zenith_angle: 876
# Outliers in cloud_solar_azimuth_angle: 0
# Outliers in cloud_solar_zenith_angle: 1095
# Outliers in cloud_surface_albedo: 369
# Outliers in formaldehyde_cloud_fraction: 1732
# Outliers in formaldehyde_hcho_slant_column_number_density: 1262
# Outliers in formaldehyde_sensor_azimuth_angle: 0
# Outliers in formaldehyde_sensor_zenith_angle: 2451
# Outliers in formaldehyde_solar_azimuth_angle: 0
# Outliers in formaldehyde_solar_zenith_angle: 1432
# Outliers in formaldehyde_tropospheric_hcho_column_number_density: 1117
# Outliers in formaldehyde_tropospheric_hcho_column_number_density_amf: 900
# Outliers in hour: 505
# Outliers in month: 0
# Outliers in nitrogendioxide_absorbing_aerosol_index: 1805
# Outliers in nitrogendioxide_cloud_fraction: 760
# Outliers in nitrogendioxide_no2_column_number_density: 1317
# Outliers in nitrogendioxide_no2_slant_column_number_density: 875
# Outliers in nitrogendioxide_sensor_altitude: 1736
# Outliers in nitrogendioxide_sensor_azimuth_angle: 0
# Outliers in nitrogendioxide_sensor_zenith_angle: 1882
# Outliers in nitrogendioxide_solar_azimuth_angle: 0
# Outliers in nitrogendioxide_solar_zenith_angle: 1338
# Outliers in nitrogendioxide_stratospheric_no2_column_number_density: 1439
# Outliers in nitrogendioxide_tropopause_pressure: 2130
# Outliers in nitrogendioxide_tropospheric_no2_column_number_density: 1243
# Outliers in ozone_cloud_fraction: 0
# Outliers in ozone_o3_column_number_density: 461
# Outliers in ozone_o3_column_number_density_amf: 0
# Outliers in ozone_o3_effective_temperature: 115
# Outliers in ozone_o3_slant_column_number_density: 0
# Outliers in ozone_sensor_azimuth_angle: 0
# Outliers in ozone_sensor_zenith_angle: 0
# Outliers in ozone_solar_azimuth_angle: 0
# Outliers in ozone_solar_zenith_angle: 0
# Outliers in site_latitude: 2475
# Outliers in site_longitude: 2475
# Outliers in sulphurdioxide_cloud_fraction: 1515
# Outliers in sulphurdioxide_sensor_azimuth_angle: 2262
# Outliers in sulphurdioxide_sensor_zenith_angle: 1848
# Outliers in sulphurdioxide_so2_column_number_density: 1978
# Outliers in sulphurdioxide_so2_column_number_density_15km: 1679
# Outliers in sulphurdioxide_so2_column_number_density_amf: 1088
# Outliers in sulphurdioxide_so2_slant_column_number_density: 1802
# Outliers in sulphurdioxide_solar_azimuth_angle: 0
# Outliers in sulphurdioxide_solar_zenith_angle: 1453
# Outliers in uvaerosolindex_absorbing_aerosol_index: 120
# Outliers in uvaerosolindex_sensor_altitude: 54
# Outliers in uvaerosolindex_sensor_azimuth_angle: 0
# Outliers in uvaerosolindex_sensor_zenith_angle: 0
# Outliers in uvaerosolindex_solar_azimuth_angle: 0
# Outliers in uvaerosolindex_solar_zenith_angle: 4

# %%
# Calculating the IQR for numerical columns
for column in numerical_cols:
    if column != 'pm2_5':  # Exclude 'pm2_5' column
        Q1 = test_df[column].quantile(0.25)
        Q3 = test_df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = ((test_df[column] < lower_bound) | (test_df[column] > upper_bound)).sum()
        print(f"Outliers in {column}: {outliers}")
# Out:
# Outliers in carbonmonoxide_cloud_height: 0
# Outliers in carbonmonoxide_co_column_number_density: 439
# Outliers in carbonmonoxide_h2o_column_number_density: 213
# Outliers in carbonmonoxide_sensor_altitude: 16
# Outliers in carbonmonoxide_sensor_azimuth_angle: 0
# Outliers in carbonmonoxide_sensor_zenith_angle: 170
# Outliers in carbonmonoxide_solar_azimuth_angle: 0
# Outliers in carbonmonoxide_solar_zenith_angle: 291
# Outliers in cloud_cloud_base_height: 283
# Outliers in cloud_cloud_base_pressure: 304
# Outliers in cloud_cloud_fraction: 315
# Outliers in cloud_cloud_optical_depth: 230
# Outliers in cloud_cloud_top_height: 316
# Outliers in cloud_cloud_top_pressure: 298
# Outliers in cloud_sensor_azimuth_angle: 0
# Outliers in cloud_sensor_zenith_angle: 538
# Outliers in cloud_solar_azimuth_angle: 0
# Outliers in cloud_solar_zenith_angle: 400
# Outliers in cloud_surface_albedo: 35
# Outliers in formaldehyde_cloud_fraction: 0
# Outliers in formaldehyde_hcho_slant_column_number_density: 147
# Outliers in formaldehyde_sensor_azimuth_angle: 0
# Outliers in formaldehyde_sensor_zenith_angle: 0
# Outliers in formaldehyde_solar_azimuth_angle: 0
# Outliers in formaldehyde_solar_zenith_angle: 248
# Outliers in formaldehyde_tropospheric_hcho_column_number_density: 167
# Outliers in formaldehyde_tropospheric_hcho_column_number_density_amf: 332
# Outliers in hour: 309
# Outliers in month: 0
# Outliers in nitrogendioxide_absorbing_aerosol_index: 363
# Outliers in nitrogendioxide_cloud_fraction: 97
# Outliers in nitrogendioxide_no2_column_number_density: 187
# Outliers in nitrogendioxide_no2_slant_column_number_density: 157
# Outliers in nitrogendioxide_sensor_altitude: 12
# Outliers in nitrogendioxide_sensor_azimuth_angle: 0
# Outliers in nitrogendioxide_sensor_zenith_angle: 174
# Outliers in nitrogendioxide_solar_azimuth_angle: 0
# Outliers in nitrogendioxide_solar_zenith_angle: 495
# Outliers in nitrogendioxide_stratospheric_no2_column_number_density: 57
# Outliers in nitrogendioxide_tropopause_pressure: 204
# Outliers in nitrogendioxide_tropospheric_no2_column_number_density: 155
# Outliers in ozone_cloud_fraction: 0
# Outliers in ozone_o3_column_number_density: 8
# Outliers in ozone_o3_column_number_density_amf: 0
# Outliers in ozone_o3_effective_temperature: 36
# Outliers in ozone_o3_slant_column_number_density: 0
# Outliers in ozone_sensor_azimuth_angle: 0
# Outliers in ozone_sensor_zenith_angle: 0
# Outliers in ozone_solar_azimuth_angle: 0
# Outliers in ozone_solar_zenith_angle: 1
# Outliers in site_latitude: 0
# Outliers in site_longitude: 461
# Outliers in sulphurdioxide_cloud_fraction: 0
# Outliers in sulphurdioxide_sensor_azimuth_angle: 0
# Outliers in sulphurdioxide_sensor_zenith_angle: 92
# Outliers in sulphurdioxide_so2_column_number_density: 458
# Outliers in sulphurdioxide_so2_column_number_density_15km: 391
# Outliers in sulphurdioxide_so2_column_number_density_amf: 71
# Outliers in sulphurdioxide_so2_slant_column_number_density: 424
# Outliers in sulphurdioxide_solar_azimuth_angle: 0
# Outliers in sulphurdioxide_solar_zenith_angle: 437
# Outliers in uvaerosolindex_absorbing_aerosol_index: 76
# Outliers in uvaerosolindex_sensor_altitude: 0
# Outliers in uvaerosolindex_sensor_azimuth_angle: 0
# Outliers in uvaerosolindex_sensor_zenith_angle: 0
# Outliers in uvaerosolindex_solar_azimuth_angle: 0
# Outliers in uvaerosolindex_solar_zenith_angle: 1

# %% [markdown]
# #### Handling outliers for train set

# %%
# Define the percentile thresholds for winsorization
lower_percentile = 0.05  # 5th percentile
upper_percentile = 0.95  # 95th percentile

# Apply winsorization
train_df_winsorized = mstats.winsorize(train_df[column], limits=[lower_percentile, upper_percentile])

# Replace the column in the DataFrame with the winsorized values
train_df[column] = train_df_winsorized

# %% [markdown]
# #### Handling outliers for test data

# %%
# Define the percentile thresholds for winsorization
lower_percentile = 0.05  # 5th percentile
upper_percentile = 0.95  # 95th percentile

# Apply winsorization
test_df_winsorized = mstats.winsorize(test_df[column], limits=[lower_percentile, upper_percentile])

# Replace the column in the DataFrame with the winsorized values
test_df[column] = test_df_winsorized

# %%
# Calculating the IQR for numerical columns
for column in numerical_cols:
    if column != 'pm2_5':  # Exclude 'pm2_5' column
        Q1 = train_df[column].quantile(0.25)
        Q3 = train_df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = ((train_df[column] < lower_bound) | (train_df[column] > upper_bound)).sum()
        print(f"Outliers in {column}: {outliers}")
# Out:
# Outliers in carbonmonoxide_cloud_height: 1065
# Outliers in carbonmonoxide_co_column_number_density: 862
# Outliers in carbonmonoxide_h2o_column_number_density: 812
# Outliers in carbonmonoxide_sensor_altitude: 1062
# Outliers in carbonmonoxide_sensor_azimuth_angle: 0
# Outliers in carbonmonoxide_sensor_zenith_angle: 1299
# Outliers in carbonmonoxide_solar_azimuth_angle: 0
# Outliers in carbonmonoxide_solar_zenith_angle: 1225
# Outliers in cloud_cloud_base_height: 387
# Outliers in cloud_cloud_base_pressure: 51
# Outliers in cloud_cloud_fraction: 0
# Outliers in cloud_cloud_optical_depth: 1025
# Outliers in cloud_cloud_top_height: 387
# Outliers in cloud_cloud_top_pressure: 57
# Outliers in cloud_sensor_azimuth_angle: 0
# Outliers in cloud_sensor_zenith_angle: 876
# Outliers in cloud_solar_azimuth_angle: 0
# Outliers in cloud_solar_zenith_angle: 1095
# Outliers in cloud_surface_albedo: 369
# Outliers in formaldehyde_cloud_fraction: 1732
# Outliers in formaldehyde_hcho_slant_column_number_density: 1262
# Outliers in formaldehyde_sensor_azimuth_angle: 0
# Outliers in formaldehyde_sensor_zenith_angle: 2451
# Outliers in formaldehyde_solar_azimuth_angle: 0
# Outliers in formaldehyde_solar_zenith_angle: 1432
# Outliers in formaldehyde_tropospheric_hcho_column_number_density: 1117
# Outliers in formaldehyde_tropospheric_hcho_column_number_density_amf: 900
# Outliers in hour: 505
# Outliers in month: 0
# Outliers in nitrogendioxide_absorbing_aerosol_index: 1805
# Outliers in nitrogendioxide_cloud_fraction: 760
# Outliers in nitrogendioxide_no2_column_number_density: 1317
# Outliers in nitrogendioxide_no2_slant_column_number_density: 875
# Outliers in nitrogendioxide_sensor_altitude: 1736
# Outliers in nitrogendioxide_sensor_azimuth_angle: 0
# Outliers in nitrogendioxide_sensor_zenith_angle: 1882
# Outliers in nitrogendioxide_solar_azimuth_angle: 0
# Outliers in nitrogendioxide_solar_zenith_angle: 1338
# Outliers in nitrogendioxide_stratospheric_no2_column_number_density: 1439
# Outliers in nitrogendioxide_tropopause_pressure: 2130
# Outliers in nitrogendioxide_tropospheric_no2_column_number_density: 1243
# Outliers in ozone_cloud_fraction: 0
# Outliers in ozone_o3_column_number_density: 461
# Outliers in ozone_o3_column_number_density_amf: 0
# Outliers in ozone_o3_effective_temperature: 115
# Outliers in ozone_o3_slant_column_number_density: 0
# Outliers in ozone_sensor_azimuth_angle: 0
# Outliers in ozone_sensor_zenith_angle: 0
# Outliers in ozone_solar_azimuth_angle: 0
# Outliers in ozone_solar_zenith_angle: 0
# Outliers in site_latitude: 2475
# Outliers in site_longitude: 2475
# Outliers in sulphurdioxide_cloud_fraction: 1515
# Outliers in sulphurdioxide_sensor_azimuth_angle: 2262
# Outliers in sulphurdioxide_sensor_zenith_angle: 1848
# Outliers in sulphurdioxide_so2_column_number_density: 1978
# Outliers in sulphurdioxide_so2_column_number_density_15km: 1679
# Outliers in sulphurdioxide_so2_column_number_density_amf: 1088
# Outliers in sulphurdioxide_so2_slant_column_number_density: 1802
# Outliers in sulphurdioxide_solar_azimuth_angle: 0
# Outliers in sulphurdioxide_solar_zenith_angle: 1453
# Outliers in uvaerosolindex_absorbing_aerosol_index: 120
# Outliers in uvaerosolindex_sensor_altitude: 54
# Outliers in uvaerosolindex_sensor_azimuth_angle: 0
# Outliers in uvaerosolindex_sensor_zenith_angle: 0
# Outliers in uvaerosolindex_solar_azimuth_angle: 0
# Outliers in uvaerosolindex_solar_zenith_angle: 0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8071 entries, 0 to 8070
# Data columns (total 73 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   id                                                        8071 non-null   object
#  1   site_id                                                   8071 non-null   object
#  2   site_latitude                                             8071 non-null   float64
#  3   site_longitude                                            8071 non-null   float64
#  4   city                                                      8071 non-null   object
#  5   country                                                   8071 non-null   object
#  6   date                                                      8071 non-null   object
#  7   hour                                                      8071 non-null   int64
#  8   sulphurdioxide_so2_column_number_density                  8071 non-null   float64
#  9   sulphurdioxide_so2_column_number_density_amf              8071 non-null   float64
#  10  sulphurdioxide_so2_slant_column_number_density            8071 non-null   float64
#  11  sulphurdioxide_cloud_fraction                             8071 non-null   float64
#  12  sulphurdioxide_sensor_azimuth_angle                       8071 non-null   float64
#  13  sulphurdioxide_sensor_zenith_angle                        8071 non-null   float64
#  14  sulphurdioxide_solar_azimuth_angle                        8071 non-null   float64
#  15  sulphurdioxide_solar_zenith_angle                         8071 non-null   float64
#  16  sulphurdioxide_so2_column_number_density_15km             8071 non-null   float64
#  17  month                                                     8071 non-null   float64
#  18  carbonmonoxide_co_column_number_density                   8071 non-null   float64
#  19  carbonmonoxide_h2o_column_number_density                  8071 non-null   float64
#  20  carbonmonoxide_cloud_height                               8071 non-null   float64
#  21  carbonmonoxide_sensor_altitude                            8071 non-null   float64
#  22  carbonmonoxide_sensor_azimuth_angle                       8071 non-null   float64
#  23  carbonmonoxide_sensor_zenith_angle                        8071 non-null   float64
#  24  carbonmonoxide_solar_azimuth_angle                        8071 non-null   float64
#  25  carbonmonoxide_solar_zenith_angle                         8071 non-null   float64
#  26  nitrogendioxide_no2_column_number_density                 8071 non-null   float64
#  27  nitrogendioxide_tropospheric_no2_column_number_density    8071 non-null   float64
#  28  nitrogendioxide_stratospheric_no2_column_number_density   8071 non-null   float64
#  29  nitrogendioxide_no2_slant_column_number_density           8071 non-null   float64
#  30  nitrogendioxide_tropopause_pressure                       8071 non-null   float64
#  31  nitrogendioxide_absorbing_aerosol_index                   8071 non-null   float64
#  32  nitrogendioxide_cloud_fraction                            8071 non-null   float64
#  33  nitrogendioxide_sensor_altitude                           8071 non-null   float64
#  34  nitrogendioxide_sensor_azimuth_angle                      8071 non-null   float64
#  35  nitrogendioxide_sensor_zenith_angle                       8071 non-null   float64
#  36  nitrogendioxide_solar_azimuth_angle                       8071 non-null   float64
#  37  nitrogendioxide_solar_zenith_angle                        8071 non-null   float64
#  38  formaldehyde_tropospheric_hcho_column_number_density      8071 non-null   float64
#  39  formaldehyde_tropospheric_hcho_column_number_density_amf  8071 non-null   float64
#  40  formaldehyde_hcho_slant_column_number_density             8071 non-null   float64
#  41  formaldehyde_cloud_fraction                               8071 non-null   float64
#  42  formaldehyde_solar_zenith_angle                           8071 non-null   float64
#  43  formaldehyde_solar_azimuth_angle                          8071 non-null   float64
#  44  formaldehyde_sensor_zenith_angle                          8071 non-null   float64
#  45  formaldehyde_sensor_azimuth_angle                         8071 non-null   float64
#  46  uvaerosolindex_absorbing_aerosol_index                    8071 non-null   float64
#  47  uvaerosolindex_sensor_altitude                            8071 non-null   float64
#  48  uvaerosolindex_sensor_azimuth_angle                       8071 non-null   float64
#  49  uvaerosolindex_sensor_zenith_angle                        8071 non-null   float64
#  50  uvaerosolindex_solar_azimuth_angle                        8071 non-null   float64
#  51  uvaerosolindex_solar_zenith_angle                         8071 non-null   float64
#  52  ozone_o3_column_number_density                            8071 non-null   float64
#  53  ozone_o3_column_number_density_amf                        8071 non-null   float64
#  54  ozone_o3_slant_column_number_density                      8071 non-null   float64
#  55  ozone_o3_effective_temperature                            8071 non-null   float64
#  56  ozone_cloud_fraction                                      8071 non-null   float64
#  57  ozone_sensor_azimuth_angle                                8071 non-null   float64
#  58  ozone_sensor_zenith_angle                                 8071 non-null   float64
#  59  ozone_solar_azimuth_angle                                 8071 non-null   float64
#  60  ozone_solar_zenith_angle                                  8071 non-null   float64
#  61  cloud_cloud_fraction                                      8071 non-null   float64
#  62  cloud_cloud_top_pressure                                  8071 non-null   float64
#  63  cloud_cloud_top_height                                    8071 non-null   float64
#  64  cloud_cloud_base_pressure                                 8071 non-null   float64
#  65  cloud_cloud_base_height                                   8071 non-null   float64
#  66  cloud_cloud_optical_depth                                 8071 non-null   float64
#  67  cloud_surface_albedo                                      8071 non-null   float64
#  68  cloud_sensor_azimuth_angle                                8071 non-null   float64
#  69  cloud_sensor_zenith_angle                                 8071 non-null   float64
#  70  cloud_solar_azimuth_angle                                 8071 non-null   float64
#  71  cloud_solar_zenith_angle                                  8071 non-null   float64
#  72  pm2_5                                                     8071 non-null   float64
# dtypes: float64(67), int64(1), object(5)
# memory usage: 4.5+ MB

# %% [markdown]
# ### Dealing with the date column

# %%
# Convert the 'date' column to datetime format
train_df['date'] = pd.to_datetime(train_df['date'])

# Extract year, month, week from the 'date' column
train_df['year'] = train_df['date'].dt.year
train_df['month'] = train_df['date'].dt.month
train_df['week'] = train_df['date'].dt.isocalendar().week

# %%
# Convert the 'date' column to datetime format
test_df['date'] = pd.to_datetime(test_df['date'])

# Extract year, month, week from the 'date' column
test_df['year'] = test_df['date'].dt.year
test_df['month'] = test_df['date'].dt.month
test_df['week'] = test_df['date'].dt.isocalendar().week

# %%
col_drops = ['date', 'site_id', 'id']
test_df = test_df.drop(col_drops, axis=1)
train_df = train_df.drop(col_drops, axis=1)
display(train_df.shape)
display(test_df.shape)
# Out:
# (8071, 72)
# (2783, 71)

# %% [markdown]
# ### Encoding the city and country columns

# %%
# mapping the two columns
city_mapping = {'Kampala': 0, 'Nairobi': 1,
                'Lagos': 2, 'Bujumbura':3,
               'Kisumu':4, 'Gulu':5,
                'Accra':6, 'Yaoundé':7
} 
country_mapping = {
    'Uganda':0, 'Burundi':1, 
    'Kenya':2, 'Nigeria':3,
    'Cameroon':4, 'Ghana':5
}

# %%
# Replace 'outcome' values with numeric values
train_df['city'] = train_df['city'].replace(city_mapping)
test_df['city'] = test_df['city'].replace(city_mapping)

#country encoding mapping
train_df['country'] = train_df['country'].replace(country_mapping)
test_df['country'] = test_df['country'].replace(country_mapping)

# %%
display(train_df.head())
display(test_df.head())
# Out:
#    site_latitude  site_longitude  city  country  hour  \
# 0        6.53257         3.39936     2        3    13
# 1        6.53257         3.39936     2        3    12
# 2        6.53257         3.39936     2        3    13
# 3        6.53257         3.39936     2        3    14
# 4        6.53257         3.39936     2        3    13
#
#    sulphurdioxide_so2_column_number_density  \
# 0                                  0.000024
# 1                                  0.000024
# 2                                  0.000024
# 3                                  0.000024
# 4                                  0.000267
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                
#
#    formaldehyde_solar_zenith_angle  formaldehyde_solar_azimuth_angle  \
# 0                        25.512329                        -86.879776
# 1                        31.828811                       -133.251167
# 2                        16.417355                        -89.089083
# 3                        31.828811                       -133.251167
# 4                        12.226210                       -111.396515
#
#    formaldehyde_sensor_zenith_angle  formaldehyde_sensor_azimuth_angle  \
# 0                         26.926420                        -100.330299
# 1                         51.678408                          70.059709
# 2                         43.112466                          73.117264
# 3                         51.678408                          70.059709
# 4                         66.014107                          70.066956
#
#    uvaerosolindex_absorbing_aerosol_index  uvaerosolindex_sensor_altitude  \
# 0                               -0.258422                   829420.312500
# 1                               -0.408162                   829340.750000
# 2                               -0.115169                   829204.480816
# 3                               -1.116044                   829067.312500
# 4                               -0.211314                   828876.562500
#
#    uvaerosolindex_sensor_azimuth_angle  uvaerosolindex_sensor_zenith_angle  \
# 0                          -100.330299                           26.926420
# 1                            76.400116                           11.171532
# 2                            73.117264                           43.112466
# 3                            70.680077                           61.874397
# 4                            70.066956                           66.014107
#
#    uvaerosolindex_solar_azimuth_angle  uvaerosolindex_solar_zenith_angle  \
# 0                          -86.879776                          18.004797
# 1                          -87.726566                          18.004797
# 2                          -89.089083                          18.004797
# 3                          -90.875526                          18.004797
# 4                         -111.396515                          18.004797
#
#    ozone_o3_column_number_density  ozone_o3_column_number_density_amf  \
# 0                        0.126056                            2.243713
# 1                        0.126282                            2.136400
# 2                        0.126162                            2.428528
# 3                        0.121339                            3.074277
# 4                        0.127799                            3.335475
#
#    ozone_o3_slant_column_number_density  ozone_o3_effective_temperature  \
# 0                              0.286278                      230.244171
# 1                              0.273757                      230.184377
# 2                              0.311882                      237.772241
# 3                              0.378890                      225.704056
# 4                              0.432085                      237.175858
#
#    ozone_cloud_fraction  ozone_sensor_azimuth_angle  \
# 0              0.079324                 -100.330299
# 1              0.613266                   76.400116
# 2              0.164370                   73.117264
# 3              0.845910                   70.680077
# 4              0.000000                   70.066956
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  26.926420                 -86.879776
# 1                  11.171532                 -87.726566
# 2                  43.112466                 -89.089083
# 3                  61.874397                 -90.875526
# 4                  66.014107                -111.396515
#
#    ozone_solar_zenith_angle  cloud_cloud_fraction  cloud_cloud_top_pressure  \
# 0                 25.512329              0.043065              74217.403083
# 1                 20.951560              0.171229              56970.398438
# 2                 16.417355              0.171229              56970.398438
# 3                 11.865146              0.845911              46052.449219
# 4                 12.226210              0.171229              56970.398438
#
#    cloud_cloud_top_height  cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0             2710.544562               83569.504246              1710.544483
# 1             4951.748535               64716.386719              3951.748291
# 2             4951.748535               64716.386719              3951.748291
# 3             6585.034668               52160.980469              5585.034668
# 4             4951.748535               64716.386719              3951.748291
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                   3.063105              0.263193
# 1                   6.390105              0.258624
# 2                   6.390105              0.258624
# 3                  29.145922              0.314945
# 4                   6.390105              0.258624
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                 -100.317077                  27.059646
# 1                   70.039436                  53.184719
# 2                   70.039436                  53.184719
# 3                   70.680077                  61.874222
# 4                   70.039436                  53.184719
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle  year  week
# 0                 -86.885670                 25.530511  2023    36
# 1                -133.105549                 29.519972  2023    36
# 2                -133.105549                 29.519972  2023    36
# 3                 -90.875603                 11.865201  2023    36
# 4                -133.105549                 29.519972  2023    38

# %%
# Select X and y features for modelling
X = train_df.drop('pm2_5', axis = 1)
y = train_df.pm2_5

test_df = test_df[X.columns]
test_df.head()
# Out:
#    site_latitude  site_longitude  city  country  hour  \
# 0        5.61252        -0.22955     6        5    13
# 1        5.61252        -0.22955     6        5    13
# 2        5.61252        -0.22955     6        5    13
# 3        5.61252        -0.22955     6        5    12
# 4        5.61252        -0.22955     6        5    12
#
#    sulphurdioxide_so2_column_number_density  \
# 0                                 -0.000072
# 1                                  0.000097
# 2                                 -0.000051
# 3                                  0.000097
# 4                                 -0.000634
#
#    sulphurdioxide_so2_column_number_density_amf  \
# 0                                      0.762543
# 1                                      0.659439
# 2                                      1.004265
# 3                                      0.659439
# 4                                      0.632173
#
#    sulphurdioxide_so2_slant_column_number_density  \
# 0                
#
#    formaldehyde_sensor_zenith_angle  formaldehyde_sensor_azimuth_angle  \
# 0                         26.926420                        -100.330299
# 1                         51.678408                          70.059709
# 2                         43.112466                          73.117264
# 3                         51.678408                          70.059709
# 4                         66.014107                          70.066956
#
#    uvaerosolindex_absorbing_aerosol_index  uvaerosolindex_sensor_altitude  \
# 0                               -0.258422                   829420.312500
# 1                               -0.408162                   829340.750000
# 2                               -0.115169                   829204.480816
# 3                               -1.116044                   829067.312500
# 4                               -0.211314                   828876.562500
#
#    uvaerosolindex_sensor_azimuth_angle  uvaerosolindex_sensor_zenith_angle  \
# 0                          -100.330299                           26.926420
# 1                            76.400116                           11.171532
# 2                            73.117264                           43.112466
# 3                            70.680077                           61.874397
# 4                            70.066956                           66.014107
#
#    uvaerosolindex_solar_azimuth_angle  uvaerosolindex_solar_zenith_angle  \
# 0                          -86.879776                          18.004797
# 1                          -87.726566                          18.004797
# 2                          -89.089083                          18.004797
# 3                          -90.875526                          18.004797
# 4                         -111.396515                          18.004797
#
#    ozone_o3_column_number_density  ozone_o3_column_number_density_amf  \
# 0                        0.126056                            2.243713
# 1                        0.126282                            2.136400
# 2                        0.126162                            2.428528
# 3                        0.121339                            3.074277
# 4                        0.127799                            3.335475
#
#    ozone_o3_slant_column_number_density  ozone_o3_effective_temperature  \
# 0                              0.286278                      230.244171
# 1                              0.273757                      230.184377
# 2                              0.311882                      237.772241
# 3                              0.378890                      225.704056
# 4                              0.432085                      237.175858
#
#    ozone_cloud_fraction  ozone_sensor_azimuth_angle  \
# 0              0.079324                 -100.330299
# 1              0.613266                   76.400116
# 2              0.164370                   73.117264
# 3              0.845910                   70.680077
# 4              0.000000                   70.066956
#
#    ozone_sensor_zenith_angle  ozone_solar_azimuth_angle  \
# 0                  26.926420                 -86.879776
# 1                  11.171532                 -87.726566
# 2                  43.112466                 -89.089083
# 3                  61.874397                 -90.875526
# 4                  66.014107                -111.396515
#
#    ozone_solar_zenith_angle  cloud_cloud_fraction  cloud_cloud_top_pressure  \
# 0                 25.512329              0.043065              74217.403083
# 1                 20.951560              0.171229              56970.398438
# 2                 16.417355              0.171229              56970.398438
# 3                 11.865146              0.845911              46052.449219
# 4                 12.226210              0.171229              56970.398438
#
#    cloud_cloud_top_height  cloud_cloud_base_pressure  cloud_cloud_base_height  \
# 0             2710.544562               83569.504246              1710.544483
# 1             4951.748535               64716.386719              3951.748291
# 2             4951.748535               64716.386719              3951.748291
# 3             6585.034668               52160.980469              5585.034668
# 4             4951.748535               64716.386719              3951.748291
#
#    cloud_cloud_optical_depth  cloud_surface_albedo  \
# 0                   3.063105              0.263193
# 1                   6.390105              0.258624
# 2                   6.390105              0.258624
# 3                  29.145922              0.314945
# 4                   6.390105              0.258624
#
#    cloud_sensor_azimuth_angle  cloud_sensor_zenith_angle  \
# 0                 -100.317077                  27.059646
# 1                   70.039436                  53.184719
# 2                   70.039436                  53.184719
# 3                   70.680077                  61.874222
# 4                   70.039436                  53.184719
#
#    cloud_solar_azimuth_angle  cloud_solar_zenith_angle  year  week
# 0                 -86.885670                 25.530511  2023    36
# 1                -133.105549                 29.519972  2023    36
# 2                -133.105549                 29.519972  2023    36
# 3                 -90.875603                 11.865201  2023    36
# 4                -133.105549                 29.519972  2023    38

# %%
# Train model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn import linear_model
reg = linear_model.BayesianRidge()

reg.fit(X_train, y_train)
# Out:
# BayesianRidge()

# %%
# Make predictions on the testing data
y_pred = GBR.predict(X_test)

# Calculate RMSE using scikit-learn's mean_squared_error function
rmse = mean_squared_error(y_test, y_pred, squared=False)  # Calculate RMSE (square root of MSE)
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Root Mean Squared Error: 24.572655445843893

# %%
# Make predictions on the test set
#preds = model.predict(test_df)

# Create submission file
#sub = pd.DataFrame({'id': test['id'], 'pm2_5': preds})

# Preview sub file
#sub.head()

# %%
# Create a csv file
#sub.to_csv('submission10.csv', index = False)
